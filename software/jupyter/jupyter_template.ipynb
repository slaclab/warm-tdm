# %% [markdown]
# ### This is how every notebook would start

# %%
# %run warmTdmClientCmd.py
# Out:
# Connected to GroupRoot at localhost:9099

# %%
import warm_tdm

# %%
p = warm_tdm.JupyterPlotter(client.root)

# %%
p.plots(5, update=True)
# Out:
# WARNING:pyrogue.VirtualClient.VirtualClient:I have not heard from GroupRoot in 10 seconds. It may be busy, continuing to wait...
