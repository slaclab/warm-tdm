# %%
# %run warmTdmClientCmd.py
# Out:
# Connected to GroupRoot at localhost:9099

# %%
root = client.root
GroupRoot = root

# %%
root.Group.HardwareGroup.ColumnBoard[0].WarmTdmCore.Timing.TimingTx.ReadDevice()
root.Group.HardwareGroup.ColumnBoard[0].WarmTdmCore.Timing.TimingRx.ReadDevice()
root.Group.HardwareGroup.RowBoard[0].WarmTdmCore.Timing.TimingRx.ReadDevice()

root.Group.HardwareGroup.ColumnBoard[0].WarmTdmCore.WarmTdmCommon2.WarmTdmConfig.ReadDevice()
root.Group.HardwareGroup.RowBoard[0].WarmTdmCore.WarmTdmCommon2.WarmTdmConfig.ReadDevice()

root.Group.HardwareGroup.ColumnBoard[0].DataPath.WaveformCapture.ReadDevice()
root.Group.HardwareGroup.ColumnBoard[0].DataPath.Ad9681Readout.ReadDevice()

# %%
rdc = root.Group.HardwareGroup.RowBoard[0].RowDacDriver
rdc.ReadDevice()
rdc.Mode.setDisp('MANUAL')
for rfo in rdc.RowFasOn.values():
    currents = rfo.Current.value()
    currents = [175.0 for _ in currents]
    rfo.Current.set(currents)
for rfo in rdc.RowFasOff.values():
    currents = rfo.Current.value()
    currents = [0.0 for _ in currents]
    rfo.Current.set(currents)

currents = rdc.ChipFasOn.Current.value()
currents = [175.0 for _ in currents]
rdc.ChipFasOn.Current.set(currents)

currents = [0.0 for _ in currents]
rdc.ChipFasOff.Current.set(currents)
rdc.Mode.setDisp('TIMING')
# Out:
# Rogue/pyrogue version v6.6.2. https://github.com/slaclab/rogue
# ZmqClient::setTimeout: Setting timeout to 1000 msecs, waitRetry = 0
# ZmqClient::setTimeout: Setting timeout to 1000 msecs, waitRetry = 1
# 1769106780.183058:pyrogue.ZmqClient: Timeout waiting for response after 1.000000 Seconds, server may be busy! Waiting...
# 1769106781.183733:pyrogue.ZmqClient: Timeout waiting for response after 2.000000 Seconds, server may be busy! Waiting...
# 1769106782.184730:pyrogue.ZmqClient: Timeout waiting for response after 3.000000 Seconds, server may be busy! Waiting...
# 1769106783.185758:pyrogue.ZmqClient: Timeout waiting for response after 4.000000 Seconds, server may be busy! Waiting...
# 1769106784.186776:pyrogue.ZmqClient: Timeout waiting for response after 5.000000 Seconds, server may be busy! Waiting...
# 1769106785.187793:pyrogue.ZmqClient: Timeout waiting for response after 6.000000 Seconds, server may be busy! Waiting...
# 1769106786.188817:pyrogue.ZmqClient: Timeout waiting for response after 7.000000 Seconds, server may be busy! Waiting...
# 1769106787.189834:pyrogue.ZmqClient: Timeout waiting for response after 8.000000 Seconds, server may be busy! Waiting...
# 1769106788.190858:pyrogue.ZmqClient: Timeout waiting for response after 9.000000 Seconds, server may be busy! Waiting...
# 1769106789.191881:pyrogue.ZmqClient: Timeout waiting for response after 10.000000 Seconds, server may be busy! Waiting...
# 1769106790.192904:pyrogue.ZmqClient: Timeout waiting for response after 11.000000 Seconds, server may be busy! Waiting...
# 1769106791.193935:pyrogue.ZmqClient: Timeout waiting for response after 12.000000 Seconds, server may be busy! Waiting...
# 1769106792.194983:pyrogue.ZmqClient: Timeout waiting for response after 13.000000 Seconds, server may be busy! Waiting...
# 1769106793.196001:pyrogue.ZmqClient: Timeout waiting for response after 14.000000 Seconds, server may be busy! Waiting...
# 1769106794.197036:pyrogue.ZmqClient: Timeout waiting for response after 15.000000 Seconds, server may be busy! Waiting...
# 1769106795.198070:pyrogue.ZmqClient: Timeout waiting for response after 16.000000 Seconds, server may be busy! Waiting...
# 1769106796.199097:pyrogue.ZmqClient: Timeout waiting for response after 17.000000 Seconds, server may be busy! Waiting...
# 1769106797.200128:pyrogue.ZmqClient: Timeout waiting for response after 18.000000 Seconds, server may be busy! Waiting...
# 1769106798.200746:pyrogue.ZmqClient: Timeout waiting for response after 19.000000 Seconds, server may be busy! Waiting...
# 1769106799.201744:pyrogue.ZmqClient: Timeout waiting for response after 20.000000 Seconds, server may be busy! Waiting...
# 1769106800.201992:pyrogue.ZmqClient: Timeout waiting for response after 21.000000 Seconds, server may be busy! Waiting...
# 1769106801.202735:pyrogue.ZmqClient: Timeout waiting for response after 22.000000 Seconds, server may be busy! Waiting...
# 1769106802.203756:pyrogue.ZmqClient: Timeout waiting for response after 23.000000 Seconds, server may be busy! Waiting...
# 1769106803.204788:pyrogue.ZmqClient: Timeout waiting for response after 24.000000 Seconds, server may be busy! Waiting...
# 1769106804.188293:pyrogue.ZmqClient: Finally got response from server after 24.000000 seconds!
# 1769106807.859168:pyrogue.ZmqClient: Timeout waiting for response after 1.000000 Seconds, server may be busy! Waiting...
# 1769106808.125529:pyrogue.ZmqClient: Finally got response from server after 1.000000 seconds!
# 1769106814.844741:pyrogue.ZmqClient: Timeout waiting for response after 1.000000 Seconds, server may be busy! Waiting...
# 1769106814.882931:pyrogue.ZmqClient: Finally got response from server after 1.000000 seconds!
# 1769106815.894117:pyrogue.ZmqClient: Timeout waiting for response after 1.000000 Seconds, server may be busy! Waiting...
# 1769106815.926816:pyrogue.ZmqClient: Finally got response from server after 1.000000 seconds!
# 1769106816.938712:pyrogue.ZmqClient: Timeout waiting for response after 1.000000 Seconds, server may be busy! Waiting...
# 1769106816.968930:pyrogue.ZmqClient: Finally got response from server after 1.000000 seconds!
# 1769106817.979752:pyrog

# %%
# Configure Bias and FB
root.Group.HardwareGroup.ColumnBoard[0].SaBiasOffset.BiasCurrent[0].set(60)
root.Group.HardwareGroup.ColumnBoard[0].SaBiasOffset.OffsetVoltage[0].set(1.8)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=2.50, index=0x00)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=5.00, index=0x01)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=7.50, index=0x02)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=10.00, index=0x03)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=12.50, index=0x10)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=15.00, index=0x11)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=17.50, index=0x12)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=20.00, index=0x13)

# %%
# Configure AdcDsp
adcdsp = root.Group.HardwareGroup.ColumnBoard[0].DataPath.AdcDsp[0]
adcdsp.PidEnableRaw.set(True)

# %%
root.Group.HardwareGroup.ColumnBoard[0].WarmTdmCore.Timing.TimingTx.Mode.setDisp('Hardware')
root.Group.HardwareGroup.ColumnBoard[0].DataPath.WaveformCapture.BufferDepth.set(0xa00)
root.Group.HardwareGroup.ColumnBoard[0].DataPath.WaveformCapture.AllChannels.set(False)
root.Group.HardwareGroup.ColumnBoard[0].DataPath.WaveformCapture.SelectedChannel.set(0)

# %%
root.Group.RowIndexOrderList.set([0x00, 0x01, 0x02, 0x03, 0x10, 0x11, 0x12, 0x13])

# %%
root.Group.HardwareGroup.ColumnBoard[0].WarmTdmCore.Timing.TimingTx.StartRun()
