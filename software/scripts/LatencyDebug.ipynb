# %%
# %run warmTdmClientCmd.py
# Out:
# Connected to GroupRoot at localhost:9099

# %%
root = client.root
GroupRoot = root

# %%
root.Group.HardwareGroup.ColumnBoard[0].WarmTdmCore.Timing.TimingTx.ReadDevice()
root.Group.HardwareGroup.ColumnBoard[0].WarmTdmCore.Timing.TimingRx.ReadDevice()
root.Group.HardwareGroup.RowBoard[0].WarmTdmCore.Timing.TimingRx.ReadDevice()

root.Group.HardwareGroup.ColumnBoard[0].WarmTdmCore.WarmTdmCommon2.WarmTdmConfig.ReadDevice()
root.Group.HardwareGroup.RowBoard[0].WarmTdmCore.WarmTdmCommon2.WarmTdmConfig.ReadDevice()

root.Group.HardwareGroup.ColumnBoard[0].DataPath.WaveformCapture.ReadDevice()
root.Group.HardwareGroup.ColumnBoard[0].DataPath.Ad9681Readout.ReadDevice()

# %%
root.Group.RowMap2x6x10()
root.Group.HardwareGroup.Readout(2*6*10)

# %%
rdc = root.Group.HardwareGroup.RowBoard[0].RowDacDriver
rdc.ReadDevice()
rdc.Mode.setDisp('MANUAL')

rfo = rdc.FasOn
currents = rfo.Current.value()
currents = [175.0 for _ in currents]
rfo.Current.set(currents)

rfo = rdc.FasOff
currents = rfo.Current.value()
currents = [1.0 for _ in currents]
rfo.Current.set(currents)

    #currents = rdc.ChipFasOn.Current.value()
    #currents = [150.0 for _ in currents]
    #rdc.ChipFasOn.Current.set(currents)

    #currents = [2.0 for _ in currents]
    #rdc.ChipFasOff.Current.set(currents)
    #rdc.Mode.setDisp('TIMING')
# Out:
# 770226990.659738:pyrogue.ZmqClient: Timeout waiting for response after 2.000000 Seconds, server may be busy! Waiting...
# 1770226991.660734:pyrogue.ZmqClient: Timeout waiting for response after 3.000000 Seconds, server may be busy! Waiting...
# 1770226992.661741:pyrogue.ZmqClient: Timeout waiting for response after 4.000000 Seconds, server may be busy! Waiting...
# 1770226993.662766:pyrogue.ZmqClient: Timeout waiting for response after 5.000000 Seconds, server may be busy! Waiting...
# 1770226994.663783:pyrogue.ZmqClient: Timeout waiting for response after 6.000000 Seconds, server may be busy! Waiting...
# 1770226995.664734:pyrogue.ZmqClient: Timeout waiting for response after 7.000000 Seconds, server may be busy! Waiting...
# 1770226996.665738:pyrogue.ZmqClient: Timeout waiting for response after 8.000000 Seconds, server may be busy! Waiting...
# 1770226997.666769:pyrogue.ZmqClient: Timeout waiting for response after 9.000000 Seconds, server may be busy! Waiting...
# 1770226998.580936:pyrogue.ZmqClient: Finally got response from server after 9.000000 seconds!
# 1770227067.466813:pyrogue.ZmqClient: Timeout waiting for response after 1.000000 Seconds, server may be busy! Waiting...
# 1770227068.467774:pyrogue.ZmqClient: Timeout waiting for response after 2.000000 Seconds, server may be busy! Waiting...
# 1770227069.468792:pyrogue.ZmqClient: Timeout waiting for response after 3.000000 Seconds, server may be busy! Waiting...
# 1770227070.469812:pyrogue.ZmqClient: Timeout waiting for response after 4.000000 Seconds, server may be busy! Waiting...
# 1770227071.470758:pyrogue.ZmqClient: Timeout waiting for response after 5.000000 Seconds, server may be busy! Waiting...
# 1770227072.471794:pyrogue.ZmqClient: Timeout waiting for response after 6.000000 Seconds, server may be busy! Waiting...
# 1770227073.472819:pyrogue.ZmqClient: Timeout waiting for response after 7.000000 Seconds, server may be busy! Waiting...
# 1770227074.473748:pyrogue.ZmqClient: Timeout waiting for response after 8.000000 Seconds, server may be busy! Waiting...
# 1770227075.474646:pyrogue.ZmqClient: Timeout waiting for response after 9.000000 Seconds, server may be busy! Waiting...
# 1770227076.429201:pyrogue.ZmqClient: Finally got response from server after 9.000000 seconds!
# 1770227146.896911:pyrogue.ZmqClient: Timeout waiting for response after 1.000000 Seconds, server may be busy! Waiting...
# 1770227147.897933:pyrogue.ZmqClient: Timeout waiting for response after 2.000000 Seconds, server may be busy! Waiting...
# 1770227148.898953:pyrogue.ZmqClient: Timeout waiting for response after 3.000000 Seconds, server may be busy! Waiting...
# 1770227149.899737:pyrogue.ZmqClient: Timeout waiting for response after 4.000000 Seconds, server may be busy! Waiting...
# 1770227150.900750:pyrogue.ZmqClient: Timeout waiting for response after 5.000000 Seconds, server may be busy! Waiting...
# 1770227151.901763:pyrogue.ZmqClient: Timeout waiting for response after 6.000000 Seconds, server may be busy! Waiting...
# 1770227152.902781:pyrogue.ZmqClient: Timeout waiting for response after 7.000000 Seconds, server may be busy! Waiting...
# 1770227153.903796:pyrogue.ZmqClient: Timeout waiting for response after 8.000000 Seconds, server may be busy! Waiting...
# 1770227154.904825:pyrogue.ZmqClient: Timeout waiting for response after 9.000000 Seconds, server may be busy! Waiting...
# 1770227155.804384:pyrogue.ZmqClient: Finally got response from server after 9.000000 seconds!
# 1770227157.146144:pyrogue.ZmqClient: Timeout waiting for response after 1.000000 Seconds, server may be busy! Waiting...
# 1770227158.146667:pyrogue.ZmqClient: Timeout waiting for response after 2.000000 Seconds, server may be busy! Waiting...
# 1770227158.804175:pyrogue.ZmqClient: Finally got response from server after 2.000000 seconds!
# 1770227159.831166:pyrogue.ZmqClient: Timeout waiting for response after 1.000000 Seconds, server may be busy! Waiting...
# 1770227160.832199:pyrogue.ZmqClient: Timeout waiting for response after 2.000000 Seconds, server may be busy! Waiting...
# 1770227161.505940:pyrogue.ZmqClient: Finally got response from server after 2.000000 second

# %%
# Configure Bias and FB
root.Group.HardwareGroup.ColumnBoard[0].SaBiasOffset.BiasCurrent[0].set(60)
root.Group.HardwareGroup.ColumnBoard[0].SaBiasOffset.OffsetVoltage[0].set(1.8)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=2.50, index=0x00)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=5.00, index=0x01)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=7.50, index=0x02)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=10.00, index=0x03)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=12.50, index=0x10)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=15.00, index=0x11)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=17.50, index=0x12)
root.Group.HardwareGroup.ColumnBoard[0].SAFb.Column[0].Current.set(value=20.00, index=0x13)

# %%
# Configure AdcDsp
adcdsp = root.Group.HardwareGroup.ColumnBoard[0].DataPath.AdcDsp[0]
adcdsp.PidEnableRaw.set(True)

# %%
root.Group.HardwareGroup.ColumnBoard[0].WarmTdmCore.Timing.TimingTx.Mode.setDisp('Hardware')
root.Group.HardwareGroup.ColumnBoard[0].DataPath.WaveformCapture.BufferDepth.set(0xa00)
root.Group.HardwareGroup.ColumnBoard[0].DataPath.WaveformCapture.AllChannels.set(False)
root.Group.HardwareGroup.ColumnBoard[0].DataPath.WaveformCapture.SelectedChannel.set(0)

# %%
root.Group.RowIndexOrderList.set([0x00, 0x01, 0x02, 0x03, 0x10, 0x11, 0x12, 0x13, 
                                  0x80, 0x81, 0x82, 0x83, 0x90, 0x91, 0x92, 0x93])

# %%
root.Group.HardwareGroup.ColumnBoard[0].WarmTdmCore.Timing.TimingTx.StartRun()
